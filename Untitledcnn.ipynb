# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, MaxPooling1D, Dropout,Input
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("stressanalysis.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Systolic BP (mmHg)           100 non-null    int64
#  1   Diastolic BP (mmHg)          100 non-null    int64
#  2   Pupil Dilation (mm)          100 non-null    float64
#  3   Cortisol Levels (Âµg/dL)     100 non-null    float64
#  4   Extremity Temperature (Â°C)  100 non-null    float64
#  5   SpO2 Levels (%)              100 non-null    float64
#  6   Stress Level                 100 non-null    object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#        Systolic BP (mmHg)  Diastolic BP (mmHg)  Pupil Dilation (mm)  \
# count          100.000000            100.00000           100.000000
# mean           115.310000             73.47000             3.107043
# std             12.583214              8.51197             1.031757
# min             90.000000             60.00000             1.119082
# 25%            106.750000             67.00000             2.365894
# 50%            113.500000             73.50000             3.062522
# 75%            123.000000             79.00000             3.669535
# max            140.000000             90.00000             6.057283
#
#        Cortisol Levels (Âµg/dL)  Extremity Temperature (Â°C)  SpO2 Levels (%)
# count                100.000000                   100.000000       100.000000
# mean                  13.076464                    31.092489        97.602755
# std                    3.711392                     1.931362         1.750524
# min                    5.000000                    25.898013        91.709616
# 25%                   10.227762                    29.869521        96.585768
# 50%                   13.099197                    30.997882        97.650425
# 75%                   15.703875                    32.345896        98.946717
# max                   24.098194                    36.000000       100.000000

# %%
label_encoder = LabelEncoder()
df['Stress Level'] = label_encoder.fit_transform(df['Stress Level'])

# %%
x = df.drop(columns=['Stress Level'])
y = df['Stress Level']

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled = np.array(x_scaled)
y = np.array(y)

# %%
x_scaled[:5], y[:5], label_encoder.classes_
# Out:
# (array([[ 1.01356696, -0.29164146, -0.77341981, -0.70307049,  1.47901739,
#          -1.38685892],
#         [ 0.29472514,  0.29872587, -0.2876384 ,  0.24045988, -1.13279013,
#          -0.25852445],
#         [ 1.97202271, -1.59044958,  0.59098509, -2.18709099, -0.05284771,
#          -0.29920395],
#         [-0.50398798,  0.65294626,  0.53464395,  2.98466369,  0.45194971,
#          -1.97378394],
#         [-1.06308717, -0.40971492, -0.6832987 , -0.83899605,  0.46523476,
#           1.37634331]]),
#  array([2, 1, 0, 0, 1]),
#  array(['high', 'low', 'medium'], dtype=object))

# %%
unique_labels = np.unique(y)
print("Unique labels in y:", unique_labels)
# Out:
# Unique labels in y: [0 1 2]

# %%
assert all(label in [0, 1, 2] for label in unique_labels), "Found unexpected label in y."

# %%
y_categorical = to_categorical(y, num_classes=3)

# %%
print("Shape of y:", y.shape)
print("Shape of y_categorical:", y_categorical.shape)
# Out:
# Shape of y: (100,)
# Shape of y_categorical: (100, 3)

# %%
df
# Out:
#     Systolic BP (mmHg)  Diastolic BP (mmHg)  Pupil Dilation (mm)  \
# 0                  128                   71             2.313061
# 1                  119                   76             2.811757
# 2                  140                   60             3.713739
# 3                  109                   79             3.655900
# 4                  102                   70             2.405578
# ..                 ...                  ...                  ...
# 95                 110                   63             5.537056
# 96                 124                   90             4.583276
# 97                 107                   77             3.436045
# 98                 123                   76             2.027071
# 99                 112                   60             2.983879
#
#     Cortisol Levels (Âµg/dL)  Extremity Temperature (Â°C)  SpO2 Levels (%)  \
# 0                  10.480173                    33.934689        95.187194
# 1                  13.964431                    28.915628        97.152470
# 2                   5.000000                    30.990933        97.081616
# 3                  24.098194                    31.960993        94.164917
# 4                   9.978229                    31.986522       100.000000
# ..                       ...                          ...              ...
# 95                 15.934073                    30.811590        95.199750
# 96                 10.749090                    33.710457        94.452352
# 97                 12.523707                    31.469699       100.000000
# 98                 14.034732                    29.829061       100.000000
# 99                 16.743179                    30.668149        98.094474
#
#     Stress Level
# 0              2
# 1              1
# 2              0
# 3              0
# 4              1
# ..           ...
# 95             2
# 96             0
# 97             1
# 98             2
# 99             2
#
# [100 rows x 7 columns]

# %%
x
# Out:
#     Systolic BP (mmHg)  Diastolic BP (mmHg)  Pupil Dilation (mm)  \
# 0                  128                   71             2.313061
# 1                  119                   76             2.811757
# 2                  140                   60             3.713739
# 3                  109                   79             3.655900
# 4                  102                   70             2.405578
# ..                 ...                  ...                  ...
# 95                 110                   63             5.537056
# 96                 124                   90             4.583276
# 97                 107                   77             3.436045
# 98                 123                   76             2.027071
# 99                 112                   60             2.983879
#
#     Cortisol Levels (Âµg/dL)  Extremity Temperature (Â°C)  SpO2 Levels (%)
# 0                  10.480173                    33.934689        95.187194
# 1                  13.964431                    28.915628        97.152470
# 2                   5.000000                    30.990933        97.081616
# 3                  24.098194                    31.960993        94.164917
# 4                   9.978229                    31.986522       100.000000
# ..                       ...                          ...              ...
# 95                 15.934073                    30.811590        95.199750
# 96                 10.749090                    33.710457        94.452352
# 97                 12.523707                    31.469699       100.000000
# 98                 14.034732                    29.829061       100.000000
# 99                 16.743179                    30.668149        98.094474
#
# [100 rows x 6 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)

# %%
x_train
# Out:
# array([[[ 6.94081708e-01],
#         [ 1.12524012e+00],
#         [-1.04424043e+00],
#         [ 2.87672622e-01],
#         [ 4.95674958e-01],
#         [ 3.75835692e-01]],
#
#        [[ 9.33695646e-01],
#         [ 1.80652402e-01],
#         [ 5.88957693e-01],
#         [-1.81409195e+00],
#         [ 1.07241657e+00],
#         [ 1.37634331e+00]],
#
#        [[-1.84502733e-01],
#         [-8.82008785e-01],
#         [ 2.87383795e+00],
#         [-3.74047575e-01],
#         [ 5.85392857e-01],
#         [ 2.66194295e-01]],
#
#        [[ 5.51112058e-02],
#         [-5.54945287e-02],
#         [ 8.83158150e-01],
#         [-3.59071517e-01],
#         [ 1.63959443e+00],
#         [ 4.03312561e-02]],
#
#        [[-1.22282980e+00],
#         [ 1.12524012e+00],
#         [ 1.41897421e-02],
#         [-8.84907464e-01],
#         [-4.07385061e-01],
#         [ 1.37634331e+00]],
#
#        [[ 2.94725144e-01],
#         [-1.59044958e+00],
#         [ 9.95812468e-01],
#         [ 1.04178367e+00],
#         [-7.14891308e-01],
#         [-7.57761600e-01]],
#
#        [[ 4.54467770e-01],
#         [-7.63935320e-01],
#         [ 7.74626928e-01],
#         [-2.46682005e-01],
#         [-9.20318315e-01],
#         [ 1.37634331e+00]],
#
#        [[ 6.94081708e-01],
#         [ 1.95175438e+00],
#         [ 1.43800319e+00],
#         [-6.30248421e-01],
#         [ 1.36233217e+00],
#         [-1.80875747e+00]],
#
#        [[ 1.97202271e+00],
#         [-7.63935320e-01],
#         [ 1.32885678e+00],
#         [ 5.90264609e-03],
#         [-5.00522779e-01],
#         [-1.36180528e+00]],
#
#        [[ 2.14853831e-01],
#         [ 1.95175438e+00],
#         [-6.96865141e-02],
#         [ 1.79669779e-01],
#         [-1.39597138e+00],
#         [ 1.02403152e+00]],
#
#        [[-1.84502733e-01],
#         [ 1.59753398e+00],
#         [-1.17769390e+00],
#         [ 1.29687407e-01],
#         [ 5.25847004e-02],
#         [ 3.86614813e-01]],
#
#        [[-1.62218636e+00],
#         [ 1.80652402e-01],
#         [-2.35475340e-01],
#         [ 1.42185385e+00],
#         [-3.88542057e-01],
#         [ 5.18426285e-01]],
#
#        [[ 3.74596457e-01],
#         [ 6.25789366e-02],
#         [ 1.64407351e-01],
#         [-6.94117614e-01],
#         [ 3.47182947e-02],
#         [ 5.34309452e-01]],
#
#        [[-2.64374045e-01],
#         [-5.54945287e-02],
#         [-1.01901609e+00],
#         [ 8.22598422e-02],
#         [-2.06103608e+00],
#         [-6.42232901e-02]],
#
#        [[ 5.51112058e-02],
#         [ 4.16799332e-01],
#         [-6.54499871e-01],
#         [ 7.94203237e-01],
#         [ 6.37849517e-01],
#         [ 1.37634331e+00]],
#
#        [[ 5.34339082e-01],
#         [ 1.47946052e+00],
#         [-5.44207280e-01],
#         [ 1.06152574e+00],
#         [-7.09596042e-01],
#         [-2.53696454e-01]],
#
#        [[-1.46244374e+00],
#         [ 1.95175438e+00],
#         [-4.71494538e-01],
#         [ 8.02326210e-01],
#         [-8.82467639e-01],
#         [ 1.18925536e+00]],
#
#        [[-1.06308717e+00],
#         [ 6.25789366e-02],
#         [-9.49695322e-02],
#         [-8.16371881e-01],
#         [-2.04304270e+00],
#         [-4.43177795e-01]],
#
#        [[ 6.94081708e-01],
#         [ 1.83368092e+00],
#         [-1.43821185e-01],
#         [-2.12363811e-01],
#         [ 1.43400237e+00],
#         [-1.17514980e-01]],
#
#        [[ 7.73953021e-01],
#         [-4.09714924e-01],
#         [-1.29144231e+00],
#         [-8.12418884e-01],
#         [ 8.95666748e-01],
#         [ 1.37634331e+00]],
#
#        [[ 1.49279484e+00],
#         [ 6.52946263e-01],
#         [-1.93647851e+00],
#         [-7.57757628e-01],
#         [-1.82083887e+00],
#         [-8.37099778e-01]],
#
#        [[-1.94167161e+00],
#         [ 4.16799332e-01],
#         [ 6.41993352e-01],
#         [-1.69635533e+00],
#         [-5.68281845e-01],
#         [ 1.37634331e+00]],
#
#        [[ 5.34339082e-01],
#         [ 1.47946052e+00],
#         [-1.74375634e+00],
#         [ 6.40985634e-03],
#         [ 6.89185892e-01],
#         [ 1.37634331e+00]],
#
#        [[-4.24116671e-01],
#         [-1.23622918e+00],
#         [ 2.36708329e+00],
#         [ 7.73835166e-01],
#         [-1.46173900e-01],
#         [-1.37965006e+00]],
#
#        [[ 5.51112058e-02],
#         [-1.73567994e-01],
#         [ 1.30990867e+00],
#         [ 3.21927281e-01],
#         [-5.38909135e-02],
#         [-1.55130295e+00]],
#
#        [[-5.03987984e-01],
#         [ 1.80652402e-01],
#         [-7.88062861e-01],
#         [ 1.84371302e+00],
#         [ 7.61498029e-01],
#         [ 1.30928434e+00]],
#
#        [[-1.22282980e+00],
#         [-1.59044958e+00],
#         [ 4.00394814e-01],
#         [-3.94377471e-01],
#         [-6.84038011e-01],
#         [ 1.31622530e-01]],
#
#        [[ 1.17330958e+00],
#         [ 4.16799332e-01],
#         [-3.39198848e-02],
#         [ 1.03155952e+00],
#         [-8.98428635e-01],
#         [-3.46323276e-01]],
#
#        [[ 1.41292352e+00],
#         [ 7.71019728e-01],
#         [ 3.08659819e-01],
#         [ 1.09875171e+00],
#         [ 3.01701023e-01],
#         [ 1.28277244e-01]],
#
#        [[-6.63730609e-01],
#         [ 1.80652402e-01],
#         [-1.72128295e+00],
#         [-2.18709099e+00],
#         [ 1.75575534e+00],
#         [-1.02913039e+00]],
#
#        [[ 1.34982519e-01],
#         [ 5.34872798e-01],
#         [-2.27695302e-02],
#         [ 2.44141876e-01],
#         [-6.12130639e-01],
#         [-5.52988825e-01]],
#
#        [[-5.03987984e-01],
#         [ 6.52946263e-01],
#         [ 5.34643948e-01],
#         [ 2.98466369e+00],
#         [ 4.51949706e-01],
#         [-1.97378394e+00]],
#
#        [[-1.14295849e+00],
#         [-2.91641459e-01],
#         [ 1.37770470e+00],
#         [ 3.77977873e-02],
#         [ 1.40915150e+00],
#         [-6.76584226e-01]],
#
#        [[ 2.14853831e-01],
#         [ 1.00716666e+00],
#         [-3.97303134e-01],
#         [ 2.10265000e+00],
#         [-9.77129141e-02],
#         [ 1.08865711e+00]],
#
#        [[-4.24116671e-01],
#         [-1.23622918e+00],
#         [ 2.86836926e-01],
#         [ 7.93491512e-01],
#         [-4.73520834e-01],
#         [ 1.30624218e+00]],
#
#        [[-1.54231505e+00],
#         [ 1.80652402e-01],
#         [ 1.64952880e+00],
#         [-6.69942893e-02],
#         [-3.72335240e-01],
#         [-1.06285467e+00]],
#
#        [[-8.23473235e-01],
#         [ 5.34872798e-01],
#         [-1.08873435e+00],
#         [ 8.83556404e-01],
#         [-3.07198764e-01],
#         [-8.96575359e-01]],
#
#        [[ 5.34339082e-01],
#         [ 1.71560745e+00],
#         [ 4.61540777e-01],
#         [-8.18476758e-02],
#         [ 2.96366068e-01],
#         [ 1.37634331e+00]],
#
#        [[-1.22282980e+00],
#         [-1.73567994e-01],
#         [-1.79844809e+00],
#         [-3.63830661e-01],
#         [ 5.63852412e-01],
#         [ 4.63281801e-02]],
#
#        [[-9.03344547e-01],
#         [ 1.95175438e+00],
#         [ 4.38320128e-01],
#         [-4.88735294e-01],
#         [ 3.59315763e-02],
#         [ 7.36377843e-01]],
#
#        [[-3.44245358e-01],
#         [ 1.47946052e+00],
#         [-3.57665629e-01],
#         [-1.03140704e+00],
#         [ 9.36231585e-01],
#         [ 1.93559360e-01]],
#
#        [[-2.64374045e-01],
#         [-1.59044958e+00],
#         [-1.19973904e-01],
#         [ 9.92939440e-01],
#         [-2.20817356e-01],
#         [ 2.82313374e-01]],
#
#        [[-2.02154293e+00],
#         [ 6.25789366e-02],
#         [ 1.92965975e+00],
#         [-1.27343962e+00],
#         [-2.04934713e-01],
#         [ 4.79604712e-01]],
#
#        [[-1.04631420e-01],
#         [-7.63935320e-01],
#         [-2.17350082e-01],
#         [ 7.60453797e-01],
#         [-1.42474327e-01],
#         [ 1.44068811e-02]],
#
#        [[ 6.14210395e-01],
#         [-1.47237611e+00],
#         [-1.33679947e+00],
#         [-5.15412630e-01],
#         [-1.46800241e+00],
#         [ 5.10298490e-02]],
#
#        [[-9.03344547e-01],
#         [-1.59044958e+00],
#         [-7.78383872e-01],
#         [-8.72229675e-01],
#         [-5.47036480e-01],
#         [ 1.37634331e+00]],
#
#        [[-2.64374045e-01],
#         [-4.09714924e-01],
#         [ 4.68304210e-01],
#         [-8.92328622e-01],
#         [-1.45535272e-01],
#         [ 1.15319444e-02]],
#
#        [[ 6.14210395e-01],
#         [ 6.25789366e-02],
#         [-1.18765318e+00],
#         [ 2.57708146e-01],
#         [-1.51587168e+00],
#         [ 1.37634331e+00]],
#
#        [[-9.03344547e-01],
#         [ 5.34872798e-01],
#         [ 7.00775923e-02],
#         [-3.74857012e-01],
#         [ 1.75520744e+00],
#         [ 3.95924641e-01]],
#
#        [[-6.63730609e-01],
#         [ 4.16799332e-01],
#         [ 3.20482344e-01],
#         [-1.49685420e-01],
#         [ 1.96291512e-01],
#         [ 1.37634331e+00]],
#
#        [[-7.43601922e-01],
#         [-1.11815572e+00],
#         [ 5.34708242e-01],
#         [ 5.23070040e-01],
#         [-6.29387225e-01],
#         [-1.23271568e+00]],
#
#        [[-4.24116671e-01],
#         [-1.59044958e+00],
#         [-9.76424691e-01],
#         [ 6.13774631e-01],
#         [ 9.70091551e-01],
#         [ 8.69842478e-02]],
#
#        [[ 2.14853831e-01],
#         [-5.27788390e-01],
#         [-2.30866691e-01],
#         [ 4.86284824e-01],
#         [ 1.85032501e+00],
#         [-1.74562061e+00]],
#
#        [[-1.04631420e-01],
#         [-1.59044958e+00],
#         [ 1.83815307e+00],
#         [ 5.99616480e-01],
#         [ 8.40181417e-01],
#         [ 8.30005250e-01]],
#
#        [[ 6.14210395e-01],
#         [ 2.98725867e-01],
#         [-1.05200401e+00],
#         [ 2.59497266e-01],
#         [-6.57460180e-01],
#         [ 1.37634331e+00]],
#
#        [[-3.44245358e-01],
#         [ 5.34872798e-01],
#         [-5.86477563e-01],
#         [ 7.34929550e-01],
#         [-1.02376729e+00],
#         [-1.86213833e-01]],
#
#        [[-5.03987984e-01],
#         [ 7.71019728e-01],
#         [ 1.03858608e+00],
#         [ 5.43732817e-01],
#         [ 2.61370507e-01],
#         [ 6.52708124e-01]],
#
#        [[-3.44245358e-01],
#         [-5.54945287e-02],
#         [-2.08279243e-01],
#         [ 6.50190389e-01],
#         [-1.37853656e+00],
#         [-4.22748698e-01]],
#
#        [[ 6.14210395e-01],
#         [-1.23622918e+00],
#         [-1.08924915e+00],
#         [ 1.08568370e+00],
#         [ 3.30036773e-01],
#         [-3.06298355e-01]],
#
#        [[-1.14295849e+00],
#         [-5.54945287e-02],
#         [-4.17414098e-01],
#         [-1.31869466e+00],
#         [ 1.15165755e+00],
#         [ 7.53312917e-01]],
#
#        [[-1.46244374e+00],
#         [ 7.71019728e-01],
#         [ 1.66389121e+00],
#         [-9.78675439e-01],
#         [-2.75671074e-01],
#         [ 1.37634331e+00]],
#
#        [[ 5.34339082e-01],
#         [ 5.34872798e-01],
#         [-1.40569902e+00],
#         [ 5.94648392e-01],
#         [ 1.11985630e+00],
#         [ 1.37634331e+00]],
#
#        [[ 1.17330958e+00],
#         [-5.27788390e-01],
#         [ 3.38656735e-01],
#         [-1.25815339e+00],
#         [ 9.91984864e-01],
#         [ 1.17418369e+00]],
#
#        [[-1.30270111e+00],
#         [-8.82008785e-01],
#         [-1.26109220e+00],
#         [-4.22823444e-01],
#         [ 3.73328020e-01],
#         [-8.39957284e-01]],
#
#        [[ 2.94725144e-01],
#         [ 2.98725867e-01],
#         [-2.87638402e-01],
#         [ 2.40459881e-01],
#         [-1.13279013e+00],
#         [-2.58524450e-01]],
#
#        [[ 1.97202271e+00],
#         [ 1.12524012e+00],
#         [-2.28092843e-01],
#         [ 7.03687598e-01],
#         [-4.56156841e-02],
#         [-1.63999899e-01]],
#
#        [[ 1.97202271e+00],
#         [-4.09714924e-01],
#         [ 6.09466612e-01],
#         [-4.02705413e-02],
#         [-1.16121775e+00],
#         [-1.45810049e+00]],
#
#        [[ 1.97202271e+00],
#         [-1.59044958e+00],
#         [ 5.90985093e-01],
#         [-2.18709099e+00],
#         [-5.28477070e-02],
#         [-2.99203954e-01]],
#
#        [[-2.64374045e-01],
#         [-5.54945287e-02],
#         [-1.12720783e+00],
#         [-8.13237807e-01],
#         [ 7.56949844e-01],
#         [ 2.03859911e-01]],
#
#        [[-5.83859296e-01],
#         [ 5.34872798e-01],
#         [-1.38832945e-01],
#         [-1.32529020e+00],
#         [-9.07535761e-01],
#         [-2.15421343e-03]],
#
#        [[ 8.53824334e-01],
#         [ 2.98725867e-01],
#         [-7.16954025e-01],
#         [-3.08590858e-01],
#         [ 2.20493923e+00],
#         [-3.38345890e+00]],
#
#        [[-4.24116671e-01],
#         [-6.45861855e-01],
#         [ 1.32550653e+00],
#         [ 3.23754353e-01],
#         [ 2.55375939e+00],
#         [-2.45057991e-01]],
#
#        [[-3.44245358e-01],
#         [-8.82008785e-01],
#         [ 5.87576129e-01],
#         [ 2.52433736e-01],
#         [-9.56910067e-01],
#         [-2.69461068e-01]],
#
#        [[-1.84502733e-01],
#         [-1.59044958e+00],
#         [-1.64697496e-01],
#         [-9.13176233e-02],
#         [ 7.52913270e-02],
#         [-3.43193974e-01]],
#
#        [[ 4.54467770e-01],
#         [ 1.12524012e+00],
#         [ 4.87544740e-01],
#         [-1.90219606e+00],
#         [-5.92573022e-01],
#         [-1.39087243e-01]],
#
#        [[ 5.51112058e-02],
#         [ 1.71560745e+00],
#         [ 2.28243874e+00],
#         [ 1.47602781e+00],
#         [ 2.96284546e-01],
#         [ 1.47982103e-01]],
#
#        [[-6.63730609e-01],
#         [-7.63935320e-01],
#         [ 1.21875016e+00],
#         [ 3.45332401e-01],
#         [ 2.12046422e-01],
#         [-7.87139858e-01]],
#
#        [[-5.03987984e-01],
#         [ 7.71019728e-01],
#         [ 5.32415623e-01],
#         [-1.12810598e+00],
#         [-1.45800118e+00],
#         [ 8.26527293e-01]],
#
#        [[ 1.41292352e+00],
#         [-1.59044958e+00],
#         [-9.68801214e-01],
#         [-1.39886418e+00],
#         [ 1.86407609e+00],
#         [ 5.57830945e-01]],
#
#        [[-1.04631420e-01],
#         [-6.45861855e-01],
#         [ 4.40507145e-01],
#         [-9.75514834e-01],
#         [-6.24445671e-01],
#         [-1.18391064e+00]]])

# %%
model = Sequential([
    Input(shape=(x_train.shape[1], 1)),
    Conv1D(filters=64, kernel_size=2, activation='relu'),
    MaxPooling1D(pool_size=1),  # Adjusted pooling size
    Dropout(0.2),
    Conv1D(filters=32, kernel_size=2, activation='relu'),
    MaxPooling1D(pool_size=1),  # Adjusted pooling size
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.2607 - loss: 1.1159 - val_accuracy: 0.4500 - val_loss: 1.0444
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4636 - loss: 1.0568 - val_accuracy: 0.6500 - val_loss: 1.0191
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5482 - loss: 1.0016 - val_accuracy: 0.6000 - val_loss: 0.9976
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6806 - loss: 0.9262 - val_accuracy: 0.6000 - val_loss: 0.9703
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4854 - loss: 0.9821 - val_accuracy: 0.6000 - val_loss: 0.9467
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7318 - loss: 0.8969 - val_accuracy: 0.6000 - val_loss: 0.9139
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6515 - loss: 0.8561 - val_accuracy: 0.6000 - val_loss: 0.8494
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7053 - loss: 0.7802 - val_accuracy: 0.7000 - val_loss: 0.8110
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6333 - loss: 0.7305 - val_accuracy: 0.7000 - val_loss: 0.7810
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7448 - loss: 0.6928 - val_accuracy: 0.7500 - val_loss: 0.7777
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8211 - loss: 0.6228 - val_accuracy: 0.7500 - val_loss: 0.7750
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7269 - loss: 0.6813 - val_accuracy: 0.7500 - val_loss: 0.7121
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7893 - loss: 0.6057 - val_accuracy: 0.7500 - val_loss: 0.6283
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8676 - loss: 0.5758 - val_accuracy: 0.8000 - val_loss: 0.6431
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7939 - loss: 0.5047 - val_accuracy: 0.8000 - val_loss: 0.6342
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8125 - loss: 0.5072 - val_accuracy: 0.8000 - val_loss: 0.5496
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7843 - loss: 0.5085 - val_accuracy: 0.8500 - val_loss: 0.5766
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8335 - loss: 0.4695 - val_accuracy: 0.8500 - val_loss: 0.5609
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8507 - loss: 0.4024 - val_accuracy: 0.8500 - val_loss: 0.5563
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8335 - loss: 0.4066 - val_accuracy: 0.7500 - val_loss: 0.5166
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8979 - loss: 0.2817 - val_accuracy: 0.7500 - val_loss: 0.5314
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8761 - loss: 0.3178 - val_accuracy: 0.8500 - val_loss: 0.5618
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8429 - loss: 0.3399 - val_accuracy: 0.8500 - val_loss: 0.5963
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8402 - loss: 0.3242 - val_accuracy: 0.7500 - val_loss: 0.5271
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9303 - loss: 0.2546 - val_accuracy: 0.7500 - val_loss: 0.5509
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9484 - loss: 0.2512 - val_accuracy: 0.8500 - val_loss: 0.5923
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8851 - loss: 0.2927 - val_accuracy: 0.8500 - val_loss: 0.6375
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9024 - loss: 0.2799 - val_accuracy: 0.8000 - val_loss: 0.5858
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8884 - loss: 0.3302 - val_accuracy: 0.8000 - val_loss: 0.5839
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9211 - loss: 0.2216 - val_accuracy: 0.8500 - val_loss: 0.6281
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.2175 - val_accuracy: 0.8500 - val_loss: 0.5850
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9037 - loss: 0.2432 - val_accuracy: 0.8500 - val_loss: 0.5777
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8994 - loss: 0.2237 - val_accuracy: 0.7500 - val_loss: 0.5515
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9685 - loss: 0.1620 - val_accuracy: 0.7500 - val_loss: 0.5670
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9075 - loss: 0.2720 - val_accuracy: 0.8500 - val_loss: 0.6383
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9400 - loss: 0.1845 - val_accuracy: 0.8500 - val_loss: 0.6830
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9236 - loss: 0.1766 - val_accuracy: 0.8500 - val_loss: 0.6310
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9691 - loss: 0.1561 - val_accuracy: 0.8000 - val_loss: 0.6369
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9330 - loss: 0.2168 - val_accuracy: 0.8000 - val_loss: 0.6475
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8914 - loss: 0.2244 - val_accuracy: 0.8000 - val_loss: 0.6334
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9108 - loss: 0.2807 - val_accuracy: 0.8000 - val_loss: 0.6235
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8929 - loss: 0.2200 - val_accuracy: 0.7500 - val_loss: 0.6030
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9567 - loss: 0.1494 - val_accuracy: 0.7500 - val_loss: 0.6091
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9441 - loss: 0.2274 - val_accuracy: 0.8000 - val_loss: 0.6346
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9413 - loss: 0.2269 - val_accuracy: 0.7500 - val_loss: 0.5932
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9602 - loss: 0.1263 - val_accuracy: 0.7500 - val_loss: 0.5962
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9972 - loss: 0.1017 - val_accuracy: 0.8000 - val_loss: 0.6175
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9956 - loss: 0.1318 - val_accuracy: 0.8500 - val_loss: 0.6574
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9888 - loss: 0.0972 - val_accuracy: 0.8000 - val_loss: 0.6762
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9916 - loss: 0.1354 - val_accuracy: 0.8000 - val_loss: 0.6578

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8000 - loss: 0.6578
# Test Accuracy: 80.00%
